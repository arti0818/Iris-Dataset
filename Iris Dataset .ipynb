# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns

# %%
Iris = pd.read_csv(r'C:\Users\LENOVO\Desktop\Full stack data science class\28th - Movie and Iris set Analysis\29th\IRIS DATASET _ ADVANCE VISUALIZATION _ EDA 2\Iris.csv')

# %%
Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
Iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
Iris.shape
# Out:
# (150, 6)

# %%
Iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
Iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
len(Iris.columns)
# Out:
# 6

# %%
Iris.drop('Id',axis = 1,inplace = True)
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
Iris.isnull().any()
# Out:
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
sns.countplot(data=Iris,x=Iris['Species'])
plt.show()

# %%
Iris.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
fig = sns.jointplot(x= 'SepalLengthCm',y ='SepalWidthCm',data = Iris)

# %%
sns.jointplot(x= "SepalLengthCm",y="SepalWidthCm",data =Iris,kind = "reg")

# %%
fig =sns.jointplot(x='SepalLengthCm',y="SepalWidthCm", data = Iris, kind = 'hex')

# %%
sns.FacetGrid(Iris,hue ='Species',height = 5).map(plt.scatter,'SepalLengthCm','SepalWidthCm')\
.add_legend()

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxplot(data = Iris,x= 'Species', y = 'PetalLengthCm',order = ['Iris-virginica','Iris-versicolor','Iris-setosa'],linewidth = 2.5, orient = 'v',dodge=False)

# %%
Iris.boxplot(by='Species',figsize=(12, 6))
# Out:
# array([[<Axes: title={'center': 'PetalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'PetalWidthCm'}, xlabel='[Species]'>],
#        [<Axes: title={'center': 'SepalLengthCm'}, xlabel='[Species]'>,
#         <Axes: title={'center': 'SepalWidthCm'}, xlabel='[Species]'>]],
#       dtype=object)

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.stripplot(data = Iris,x = 'Species', y = 'SepalLengthCm', jitter=True,edgecolor='gray',size = 8,\
                   orient='v',palette='winter')

# %%
fig =plt.gcf()
fig.set_size_inches(10,7)
fig = sns.boxplot(data = Iris, x='Species',y='SepalLengthCm')
fig = sns.stripplot(data = Iris, x='Species',y='SepalLengthCm',jitter=True,edgecolor='gray',\
                    dodge =False,palette='winter')

# %%
ax = sns.boxplot(data = Iris, x= 'Species',y = 'SepalLengthCm')
ax = sns.stripplot(data = Iris, x = 'Species',y='SepalLengthCm',jitter=True, edgecolor="black")

boxtwo = ax.patches[2]
boxtwo.set_facecolor('yellow')
boxtwo.set_edgecolor('black')
boxthree = ax.patches[1]
boxthree.set_facecolor('green')
boxthree.set_edgecolor('black')
boxthree = ax.patches[0]
boxthree.set_facecolor('red')
boxthree.set_edgecolor('black')

plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.violinplot(data = Iris, x= 'Species',y='SepalLengthCm')

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.violinplot(x='Species', y ='PetalLengthCm', data = Iris)
plt.subplot(2,2,2)
sns.violinplot(data = Iris,x='Species', y='PetalWidthCm')
plt.subplot(2,2,3)
sns.violinplot(data = Iris,x='Species', y='SepalLengthCm')
plt.subplot(2,2,4)
sns.violinplot(data = Iris,x='Species', y='PetalWidthCm')
plt.show()

# %%
sns.pairplot(data= Iris,kind = 'scatter')

# %%
sns.pairplot(Iris, hue ='Species')

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.heatmap(Iris.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square ='True',mask='False',\
                 vmin=1,vmax=1,cbar_kws={'orientation':'vertical'},cbar=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 3
#       1 fig = plt.gcf()
#       2 fig.set_size_inches(10,7)
# ----> 3 fig = sns.heatmap(Iris.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square ='True',mask='False',\
#       4                  vmin=1,vmax=1,cbar_kws={'orientation':'vertical'},cbar=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# ...

# %%
Iris1 = Iris.drop('Species',axis=1)
Iris1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
fig = plt.gcf()
fig.set_size_inches(10,7)
fig = sns.heatmap(Iris1.corr(),annot=True,cmap='cubehelix',linewidths=1,linecolor='k',square=True,mask=False, vmin=-1, vmax=1,cbar_kws={"orientation": "vertical"},cbar=True)

# %%
fig=plt.gcf()
fig.set_size_inches(10,7)
Iris.hist(edgecolor = 'black',linewidth=1.5)
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
sns.set(style='darkgrid')
fig =plt.gcf()
fig.set_size_inches(10,7)
fig = sns.swarmplot(data = Iris, x= 'Species', y='PetalLengthCm',palette='winter')

# %%
sns.set(style='white')
fig =plt.gcf()
fig.set_size_inches(10,7)
fig = sns.violinplot(data = Iris, x='Species',y='PetalLengthCm')
fig = sns.swarmplot(data= Iris,x='Species',y='PetalLengthCm',color='white')

# %%
fig = sns.lmplot(data =Iris,x="PetalLengthCm", y="PetalWidthCm")

# %%
fig =sns.FacetGrid(data= Iris, hue='Species',height =6).map(sns.kdeplot,'PetalLengthCm' ).add_legend()
plt.ioff()

# %%
sns.catplot(x='Species',y='SepalLengthCm',data=Iris,kind='point')

plt.show()

# %%
sns.boxenplot(data=Iris,x='Species',y='PetalLengthCm')
plt.show()

# %%
sub = Iris[Iris['Species']=='Iris-setosa']
sns.kdeplot(data=sub[['SepalLengthCm','SepalWidthCm']], shade_lowest=False)
plt.title('Iris-setosa')
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
plt.show()

# %%
sub = Iris[Iris['Species']=='Iris-setosa']
sns.displot(data=sub[['SepalLengthCm','SepalWidthCm']], kind="kde")
plt.title('Iris-setosa')
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
plt.show()

# %%
sns.set_style('darkgrid')
f, axes =plt.subplots(2,2,figsize=(15,15))

k1 =sns.boxplot(data = Iris, x='Species',y = 'PetalLengthCm',ax=axes[0,0])
k2 = sns.violinplot(data = Iris, x='Species',y = 'PetalLengthCm',ax=axes[0,1])
k3 = sns.stripplot(data = Iris, x='Species',y = 'SepalLengthCm',ax=axes[1,0])
axes[1,1].hist(Iris.PetalLengthCm,bins=100)
plt.show()

# %%
Iris['Species']=Iris['Species'].astype('category')

# %%
list1=list()
mylabels  =list()
for gen in Iris.Species.cat.categories:
    list1.append(Iris[Iris.Species==gen].SepalLengthCm)
    mylabels .append(gen)
h=plt.hist(list1,bins=30,stacked=True,rwidth=1,label=mylabels )
plt.legend()
plt.show()

# %%
#Area plot

# %%
Iris.plot.area(y='SepalLengthCm',alpha=0.4,figsize=(12,7))
plt.show()

# %%
Iris.plot.area(y=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'],alpha=0.4,figsize=(10,7))
plt.show()

# %%
sns.displot(Iris['SepalLengthCm'],kde=True,bins=20)
plt.show()
